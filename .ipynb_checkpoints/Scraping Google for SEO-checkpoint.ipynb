# %%
# importing the neccessary dependancies

import bs4 as bs #importing beautiful script => reads the HTML
from bs4.element import Comment
import urllib.request # to request a url => gets the page
import time
import requests
import pandas as pd

# %% [markdown]
# # The objective is to get the SEO relevant info for the top ranking pages on google

# %%
# filters for visible elements dependant on from bs4.element import Comment

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = bs.BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return "\n ".join(t.strip() for t in visible_texts)

# %%
def get_txt(url):
    r  = requests.get(url,headers=USER_AGENT).text
#     r = urllib.request.urlopen(i).read()
#     soup = bs.BeautifulSoup(r.text,'lxml')    
    a = text_from_html(r)
    t = a.split(' ')
    return t
#     o.append([w for w in t if len(w)>3 and w.istitle()])
#     o.append(a)

# %%
USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

def get_seo(url):
    html_txt  = requests.get(url,headers=USER_AGENT).text
#     txt = get_txt(html_txt)
    soup = bs.BeautifulSoup(html_txt, 'html.parser')
    txt = text_from_html(html_txt)
    out = {}
    
    out['h1'] = [a.text.strip() for a in soup.findAll('h1')]
    out['h2']= [a.text.strip() for a in soup.findAll('h2')]
    out['title']= soup.title.string
    meta = []
    for tags in soup.find_all('meta'):
        meta.append(tags.get('content'))
#     out.append({'h1': h1, 'h2' : h2, 'title' : title, 'meta' : meta, 'text' : txt})
    out['meta'] = meta
    out['text'] = txt
    return out

a =  get_seo('https://intercom.com/')

# %% [markdown]
# ## Scrape function
#
# fetch_results() - gets the urls of the search results.
#
# i/p - keyword, no. of results. and language

# %%
USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# fetch google search results

def fetch_results(search_term, number_results, language_code = 'en'):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')
 
    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()
 
    return search_term, response.text

# %% [markdown]
# # Parsing the results

# %%
# Filter urls
def filter_result(url):
    exclude_list= ['youtube', 'dailymotion', 'facebook'] # exlude these websites
    return url.startswith('http') and url.split('.')[1] not in exclude_list

#Parsed results

def parse_results(html, keyword):
    soup = bs.BeautifulSoup(html, 'html.parser')
    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
#         title = result.find('h3', attrs={'class': 'r'})
        title = result.find('h3', attrs={'class': 'LC20lb'})
        description = result.find('span', attrs={'class': 'st'})
#         print(link['href'])
#         to add the other stuff - SEO related
        if link and title:
            link = link['href']
            print(link)
            title = title.get_text()
            if description:
                description = description.get_text()
            if link != '#' and filter_result(link):
                temp = get_seo(link)
                found_results.append({
                    'keyword': keyword, 
                    'rank': rank, 
                    'title': title, 
                    'description': description, 
                    'link':link, 
                    'doc':get_txt(link), 
                    'h1':temp['h1'], 
                    'h2': temp['h2'], 
                    'title' : temp['title']})
# #                 print({'keyword': keyword, 'rank': rank, 'title': title, 'description': description})
                rank += 1
#                 links.append(link)
    return(found_results)

# %%
# parse_results(fetch_results('delhi public school', 5, 'en')[1],fetch_results('delhi public school justdial', 5, 'en')[0] )
# Out:
# http://north.dpsbangalore.edu.in/
# http://east.dpsbangalore.edu.in/
# https://south.dpsbangalore.net/
# https://www.facebook.com/DelhiPublicSchoolBangaloreNorth/
# http://www.dpsfamily.org/
# [{'keyword': 'delhi public school justdial',
#   'rank': 1,
#   'title': 'Home - DPS Bangalore North',
#   'description': 'We welcome you into our world at Delhi Public school Bangalore North, an institution that promotes meaningful and joyful learning, a school where scholastic\xa0...',
#   'link': 'http://north.dpsbangalore.edu.in/',
#   'doc': ['\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '2019-20',
#    'admissions',
#    'are',
#    'open',
#    'for',
#    'classes',
#    'KG',
#    '-',
#    'IX.',
#    'To',
#    'Contact',
#    'Us\n',
#    'Click',
#    'Here\n',
#    '|',
#    'STD',
#    'XII',
#    'CBSE',
#    'Results',
#    '-2018.\n',
#    'Click',
#    'here\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Toggle',
#    'navigation\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'home\n',
#    '\n',
#    'About',
#    'Us\n',
#    '\n',
#    '\n',
#    'KKECT\n',
#    '\n',
#    'Vision',
#    '&',
#    'Mission\n',
#    '\n',
#    'School',
#    'Motto\n',
#    '\n',
#    'School',
#    'Information\n',
#    '\n',
#    '\n',
#    '\n',
#    'Academics\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'PROGRAMME\n',
#    '\n',
#    'IGCSE',
#    'Programme\n',
#    '\n',
#    'NIOS',
#    'PROGRAMME\n',
#    '\n',
#    '\n',
#    '\n',
#    'Facilities\n',
#    '\n',
#    'Admissions\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'Admissions\n',
#    '\n',
#    'IGCSE-Admissions\n',
#    '\n',
#    'NIOS',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    '\n',
#    'Resources\n',
#    '\n',
#    '\n',
#    'Blog\n',
#    '\n',
#    'Notice',
#    'Board\n',
#    '\n',
#    '\n',
#    'Student',
#    'Artwork\n',
#    '\n',
#    '\n',
#    '\n',
#    'Transfer',
#    'Certificate\n',
#    '\n',
#    '\n',
#    '\n',
#    'Contact',
#    'Us\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'home\n',
#    '\n',
#    'About',
#    'Us\n',
#    '\n',
#    '\n',
#    'KKECT\n',
#    '\n',
#    'Vision',
#    '&',
#    'Mission\n',
#    '\n',
#    'School',
#    'Motto\n',
#    '\n',
#    'School',
#    'Information\n',
#    '\n',
#    '\n',
#    '\n',
#    'Academics\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'PROGRAMME\n',
#    '\n',
#    'IGCSE',
#    'Programme\n',
#    '\n',
#    'NIOS',
#    'PROGRAMME\n',
#    '\n',
#    '\n',
#    '\n',
#    'Facilities\n',
#    '\n',
#    'Admissions\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'Admissions\n',
#    '\n',
#    'IGCSE-Admissions\n',
#    '\n',
#    'NIOS',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    '\n',
#    'Resources\n',
#    '\n',
#    '\n',
#    'Blog\n',
#    '\n',
#    'Notice',
#    'Board\n',
#    '\n',
#    '\n',
#    'Student',
#    'Artwork\n',
#    '\n',
#    '\n',
#    '\n',
#    'Transfer',
#    'Certificate\n',
#    '\n',
#    '\n',
#    '\n',
#    'Contact',
#    'Us\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'CURRICULUM\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'IGCSE',
#    'CURRICULUM\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'ENTRAR\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Message',
#    'From',
#    'the',
#    'Principal\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Dear',
#    'Parents,\n',
#    '\n',
#    'We',
#    'welcome',
#    'you',
#    'into',
#    'our',
#    'world',
#    'at',
#    'Delhi',
#    'Public',
#    'school',
#    'Bangalore',
#    'North,',
#    'an',
#    'institution',
#    'that',
#    'promotes',
#    'meaningful',
#    'and',
#    'joyful',
#    'learning,',
#    'a',
#    'school',
#    'where',
#    'scholastic',
#    'and',
#    'co-scholastic',
#    'activities',
#    'are',
#    'closely',
#    'interwoven',
#    'into',
#    'the',
#    'curricular',
#    'fabric,',
#    'a',
#    'home',
#    'away',
#    'from',
#    'home',
#    'where',
#    'students',
#    'and',
#    'teachers',
#    'share',
#    'a',
#    'relationship',
#    'of',
#    'mutual',
#    'trust,',
#    'respect,',
#    'warmth,',
#    'and',
#    'affection.\n',
#    '\n',
#    'A',
#    'Continuous',
#    'and',
#    'Comprehensive',
#    'Evaluation',
#    'system',
#    '(CCE)',
#    'caters',
#    'to',
#    'the',
#    'holistic',
#    'development',
#    'of',
#    'children',
#    'integrating',
#    'sports,',
#    'fine',
#    'arts,',
#    'yoga',
#    '&',
#    'martial',
#    'arts,',
#    'environmental',
#    'awareness,',
#    'values',
#    'and',
#    'attitudes,',
#    'life',
#    'skills',
#    'and',
#    'technology',
#    'with',
#    'scholastic',
#    'subjects.\xa0',
#    'Students’',
#    'assessment',
#    'is',
#    'based',
#    'on',
#    '21st',
#    'century',
#    'skill',
#    'development.\n',
#    '\n',
#    'Show',
#    'more\n',
#    '\n',
#    'An',
#    'inclusive',
#    'and',
#    'progressive',
#    'school',
#    'like',
#    'DPS',
#    'Bangalore',
#    'North',
#    'lays',
#    'strong',
#    'emphasis',
#    'on',
#    'personalization,',
#    'meeting',
#    'diverse',
#    'needs,',
#    'providing',
#    'equal',
#    'opportunities',
#    'for',
#    'learning',
#    'and',
#    'maintaining',
#    'high',
#    'standards',
#    'of',
#    'achievement',
#    'at',
#    'all',
#    'levels.',
#    'The',
#    'secure',
#    'environment',
#    'of',
#    'DPS',
#    'Bangalore',
#    'North',
#    'provides',
#    'children',
#    'with',
#    'opportunities',
#    'to',
#    'learn,',
#    'explore,',
#    'play,',
#    'discover',
#    'their',
#    'hidden',
#    'talents',
#    'and',
#    'make',
#    'informed',
#    'choices.\n',
#    '\n',
#    'Schooling',
#    'by',
#    'nature',
#    'is',
#    'a',
#    'social',
#    'and',
#    'cultural',
#    'undertaking.\xa0',
#    'As',
#    'the',
#    'world',
#    'shrinks',
#    'and',
#    'barriers',
#    'are',
#    'broken,',
#    'our',
#    'students',
#    'join',
#    'hands',
#    'with',
#    'their',
#    'counterparts',
#    'across',
#    'the',
#    'country',
#    '&',
#    'the',
#    'world',
#    'by',
#    'working',
#    'together',
#    'on',
#    'multiple',
#    'areas.',
#    'Through',
#    'international',
#    'exchange',
#    'programmes,',
#    'social',
#    'responsibility',
#    'initiatives,',
#    'human',
#    'rights',
#    'issues,',
#    'environment',
#    'conservation',
#    'programmes,',
#    'cultural',
#    'exchange',
#    'programmes',
#    'and',
#    'projects,',
#    'they',
#    'learn',
#    'invaluable',
#    'life',
#    'lessons',
#    'on',
#    'diversity,',
#    'equity,',
#    'tolerance',
#    'and',
#    'acceptance.\n',
#    '\n',
#    'Empowered',
#    'with',
#    'a',
#    'strong',
#    'sense',
#    'of',
#    'wellbeing,',
#    'we',
#    'are',
#    'confident',
#    'that',
#    'our',
#    'students',
#    'will',
#    'emerge',
#    'as',
#    'responsible',
#    'global',
#    'leaders',
#    'and',
#    'citizens',
#    'with',
#    'strong',
#    'moral,',
#    'ethical',
#    'and',
#    'social',
#    'values.\n',
#    '\n',
#    'Show',
#    'Less\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Introduction\n',
#    '\n',
#    '\n',
#    'Highlights\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Know',
#    'More\n',
#    '\n',
#    'Facilities\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Notice',
#    'Board\n',
#    '\n',
#    '\n',
#    '\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'March',
#    '2019\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'March',
#    '2019\n',
#    'read',
#    'more\n',
#    'DPS',
#    'International',
#    'Bangalore',
#    'North',
#    '-',
#    'Student',
#    'Artwork\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'Feb',
#    "'2019\n",
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'Feb',
#    '2019\n',
#    'read',
#    'more\n',
#    'Primary',
#    "Principal's",
#    'Newsletter',
#    '-',
#    'January',
#    '2019\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'Jan',
#    "'2019\n",
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'Jan',
#    "'2019\n",
#    'read',
#    'more\n',
#    'Principals',
#    'Newsletter',
#    '-',
#    'December',
#    '‘2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    'December',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    'December',
#    '2018\n',
#    'read',
#    'more\n',
#    "Principal's",
#    'Newsletter',
#    '-',
#    'Nov',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'Sep',
#    '-',
#    'Oct',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'Sep',
#    '-',
#    'Oct',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'Nov',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'Nov',
#    '2018\n',
#    'read',
#    'more\n',
#    "Principal's",
#    'Newsletter',
#    'October',
#    '2018\n',
#    'read',
#    'more\n',
#    "Principal's",
#    'Newsletter',
#    'for',
#    'September',
#    '2018\n',
#    'read',
#    'more\n',
#    'Another',
#    'Milestone',
#    'Achieved\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    'August',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    'August',
#    '2018\n',
#    'read',
#    'more\n',
#    'Swachhata',
#    'Shapath',
#    'Day\n',
#    'read',
#    'more\n',
#    'Dear',
#    'Renu',
#    "ma'am\n",
#    'read',
#    'more\n',
#    'Essay',
#    'of',
#    'Mahi',
#    'Kumar\n',
#    'read',
#    'more\n',
#    'Story',
#    'by',
#    'Ankit\n',
#    'read',
#    'more\n',
#    'To',
#    'Our',
#    'Beloved',
#    'Principal\n',
#    'read',
#    'more\n',
#    'sanskrit',
#    'day',
#    'report',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Secondary',
#    'Newsletter',
#    '-',
#    'July',
#    '2018\n',
#    'read',
#    'more\n',
#    'Cambridge',
#    'Primary',
#    'Newsletter',
#    '-',
#    'July',
#    '2018\n',
#    'read',
#    'more\n',
#    'IGCSE',
#    'Students',
#    'Celebrate',
#    'National',
#    'Day',
#    'of',
#    'France\n',
#    'read',
#    'more\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Testimonial\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Promila',
#    'Iyer\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'The',
#    'BEST',
#    'educational',
#    'Institution',
#    'for',
#    'complete',
#    'personality',
#    'development,',
#    'multiple',
#    'activities,',
#    'opportunities,',
#    'quality',
#    'education',
#    '&',
#    'motivation.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    ...],
#   'h1': [],
#   'h2': ['Message From the Principal',
#    'Facilities',
#    'Notice Board',
#    'Testimonial']},
#  {'keyword': 'delhi public school justdial',
#   'rank': 2,
#   'title': 'DPS BANGALORE',
#   'description': 'With the main focus of education at DPS Bangalore East being “preparing students for life”, it is our endeavour to provide a progressive curriculum that couples\xa0...',
#   'link': 'http://east.dpsbangalore.edu.in/',
#   'doc': ['\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '080-22518100',
#    '||\n',
#    '9663115148\n',
#    '\n',
#    '\n',
#    '\n',
#    'contact@east.dpsbangalore.edu.in\n',
#    '||\n',
#    'admissions@east.dpsbangalore.edu.in\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'HOME\n',
#    '\n',
#    'ABOUT',
#    'US\n',
#    '\n',
#    '\n',
#    'KKECT\n',
#    '\n',
#    'SCHOOL',
#    'MOTTO\n',
#    '\n',
#    'SCHOOL',
#    'INFORMATION\n',
#    '\n',
#    'VISION',
#    '&',
#    'MISSION\n',
#    '\n',
#    '\n',
#    '\n',
#    'ACADEMICS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'PROGRAMME\n',
#    '\n',
#    'CAMBRIDGE',
#    'PROGRAM\n',
#    '\n',
#    'NIOS',
#    'PROGRAMME\n',
#    '\n',
#    'APPLICATION',
#    'FORMS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'Application',
#    'Form\n',
#    '\n',
#    'IGCSE',
#    'Application',
#    'Form\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'FACILITIES\n',
#    '\n',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'ADMISSIONS\n',
#    '\n',
#    'CAMBRIDGE',
#    'ADMISSIONS\n',
#    '\n',
#    'NIOS',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    '\n',
#    'STUDENT',
#    'LIFE\n',
#    '\n',
#    'RESOURCES\n',
#    '\n',
#    '\n',
#    'BLOG\n',
#    '\n',
#    'TRANSFER',
#    'CERTIFICATE\n',
#    '\n',
#    '\n',
#    '\n',
#    'CONTACT',
#    'US\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'HOME\n',
#    '\n',
#    'ABOUT',
#    'US\n',
#    '\n',
#    '\n',
#    'KKECT\n',
#    '\n',
#    'SCHOOL',
#    'MOTTO\n',
#    '\n',
#    'SCHOOL',
#    'INFORMATION\n',
#    '\n',
#    'VISION',
#    '&',
#    'MISSION\n',
#    '\n',
#    '\n',
#    '\n',
#    'ACADEMICS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'PROGRAMME\n',
#    '\n',
#    'CAMBRIDGE',
#    'PROGRAM\n',
#    '\n',
#    'NIOS',
#    'PROGRAMME\n',
#    '\n',
#    'APPLICATION',
#    'FORMS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'Application',
#    'Form\n',
#    '\n',
#    'IGCSE',
#    'Application',
#    'Form\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'FACILITIES\n',
#    '\n',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'ADMISSIONS\n',
#    '\n',
#    'CAMBRIDGE',
#    'ADMISSIONS\n',
#    '\n',
#    'NIOS',
#    'ADMISSIONS\n',
#    '\n',
#    '\n',
#    '\n',
#    'STUDENT',
#    'LIFE\n',
#    '\n',
#    'RESOURCES\n',
#    '\n',
#    '\n',
#    'BLOG\n',
#    '\n',
#    'TRANSFER',
#    'CERTIFICATE\n',
#    '\n',
#    '\n',
#    '\n',
#    'CONTACT',
#    'US\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Welcome',
#    'To',
#    'Delhi',
#    'Public',
#    'School\n',
#    'Bangalore',
#    'East\n',
#    '\n',
#    'Dedicated',
#    'To',
#    'Providing\n',
#    'Comprehensive',
#    'Education\n',
#    '\n',
#    'A',
#    'School',
#    'That',
#    'Is',
#    '"',
#    'A',
#    'Class',
#    'Apart"\n',
#    '\n',
#    'Emphasizing',
#    'On',
#    'The',
#    'Developmental\n',
#    'Needs',
#    'Of',
#    'The',
#    'Child\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'CURRICULUM\n',
#    'View',
#    'More\n',
#    'CAMBRIDGE',
#    'CURRICULUM\n',
#    'View',
#    'More\n',
#    'ENTRAR\n',
#    'View',
#    'More\n',
#    '\n',
#    '\n',
#    '\n',
#    'FROM',
#    'THE',
#    'PRINCIPAL’s',
#    'DESK\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Dear',
#    'Parents,\n',
#    '\n',
#    'A',
#    'warm',
#    'welcome',
#    'to',
#    'each',
#    'one',
#    'of',
#    'you',
#    'to',
#    'yet',
#    'another',
#    'exciting',
#    'year',
#    'ahead,',
#    'at',
#    'DPS',
#    'Bangalore',
#    'East.',
#    'With',
#    'the',
#    'main',
#    'focus',
#    'of',
#    'education',
#    'at',
#    'DPS',
#    'Bangalore',
#    'East',
#    'being',
#    '“preparing',
#    'students',
#    'for',
#    'life”,',
#    'it',
#    'is',
#    'our',
#    'endeavour',
#    'to',
#    'provide',
#    'a',
#    'progressive',
#    'curriculum',
#    'that',
#    'couples',
#    'with',
#    'our',
#    'teaching',
#    'methodology',
#    'integrated',
#    'with',
#    'the',
#    'usage',
#    'of',
#    'technology,',
#    'thereby',
#    'enabling',
#    'our',
#    '“teaching-',
#    'learning”',
#    'process',
#    'to',
#    'be',
#    'ahead',
#    'of',
#    'our',
#    'times.',
#    'This',
#    'not',
#    'only',
#    'enables',
#    'each',
#    'student',
#    'to',
#    'unleash',
#    'his/her',
#    'inner',
#    'potential',
#    'but',
#    'also',
#    'helps',
#    'him/her',
#    'to',
#    'stay',
#    'abreast',
#    'of',
#    'the',
#    'subject',
#    'matter.\n',
#    'My',
#    'best',
#    'wishes',
#    'for',
#    'a',
#    'memorable',
#    '&',
#    'purposeful',
#    'academic',
#    'year',
#    'ahead.\n',
#    '\n',
#    'With',
#    'warm',
#    'regards,\n',
#    'Manila',
#    'Carvalho\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'NOTICE',
#    'BOARD\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Newsletter',
#    'from',
#    'the',
#    'Principal',
#    'Desk-March’19\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'FSM',
#    'RECITAL',
#    '2018-19\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'SCULPTURE',
#    'OF',
#    'MAGIC\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Nurturing',
#    'Creativity\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'GRADUATION',
#    'DAY',
#    '',
#    '2018-2019\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Newsletter',
#    'from',
#    'the',
#    'Principal',
#    'Desk-February’19\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'PARENT’S',
#    'SPORTS',
#    'DAY',
#    '2018-19\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'NCC',
#    'TREKKING',
#    'CAMP\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'SPORTS',
#    'NEWSLETTER',
#    '–',
#    'FEBRUARY',
#    '2019\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'BLESSING',
#    'CEREMONY',
#    '–',
#    'GRADE',
#    'X',
#    '(2018-2019)\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Result',
#    'of',
#    'stArt-Interschool',
#    'Art',
#    'competition!!\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Newsletter',
#    'from',
#    'the',
#    'Principal',
#    'Desk-January’19\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Sports',
#    'Newsletter',
#    '–',
#    'January',
#    '2019\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Pink',
#    'Day',
#    '–',
#    'Nursery\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Principal’s',
#    'Session',
#    '(Grade-X)\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'STUDENT',
#    'EXCHANGE\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'In',
#    'order',
#    'to',
#    'make',
#    'our',
#    'students',
#    'ready',
#    'for',
#    'a',
#    'globalized',
#    'world',
#    'and',
#    'create',
#    'an',
#    'opportunity',
#    'for',
#    'them',
#    'to',
#    'learn',
#    'about',
#    'other',
#    'nations',
#    'and',
#    'culture,',
#    'we',
#    'have',
#    'developed',
#    'partnerships',
#    'with',
#    'schools',
#    'around',
#    'the',
#    'world.',
#    'Our',
#    'past',
#    'student',
#    'exchange',
#    'programmes',
#    'with',
#    'Julius',
#    'Echter',
#    'Gymnasium,',
#    'Elsenfeld,',
#    'Germany',
#    'and',
#    'Over',
#    'Hall',
#    'Community',
#    'School,',
#    'Cheshire,',
#    'U.K',
#    'have',
#    'been',
#    'extremely',
#    'successful',
#    'and',
#    'helped',
#    'our',
#    'students',
#    'appreciate',
#    'other',
#    'cultures',
#    'and',
#    'societies',
#    'as',
#    'well',
#    'as',
#    'develop',
#    'a',
#    'global',
#    'outlook.\n',
#    '\n',
#    '\n',
#    '\n',
#    'TESTIMONIALS\n',
#    'What',
#    'our',
#    'Parents',
#    'have',
#    'to',
#    'say',
#    'about',
#    'Us\n',
#    'Debasis',
#    'Mandal',
#    '&',
#    'Suparna',
#    'Modak',
#    'Chowdhury\n',
#    'Parents',
#    'of',
#    'Anudeepti',
#    'Mandal\n',
#    'Few',
#    'days',
#    'back',
#    'Anudeepti',
#    'told',
#    'us',
#    "'You",
#    'know',
#    'my',
#    'teachers',
#    'are',
#    'just',
#    'like',
#    'mothers',
#    'only',
#    'they',
#    'have',
#    'more',
#    'kids',
#    "',",
#    'and',
#    'I',
#    'know',
#    'how',
#    'true',
#    'our',
#    'little',
#    'one',
#    'is',
#    '🙂',
#    '.\n',
#    '\n',
#    'We',
#    'cordially',
#    'thank',
#    'you',
#    'for',
#    'all',
#    'of',
#    'your',
#    'efforts',
#    'and',
#    'utmost',
#    'care',
#    'you',
#    'put',
#    'for',
#    'entire',
#    'session',
#    "(Jun'14",
#    'to',
#    "Mar'15)",
#    'to',
#    'shape',
#    'our',
#    'little',
#    'one',
#    'along',
#    'with',
#    'other',
#    '33',
#    'little',
#    'tiny',
#    'tots.\n',
#    '\n',
#    'Thank',
#    'you',
#    'and',
#    'DPS.\n',
#    'Manoj',
#    'Paul',
#    'and',
#    'Jubitha\n',
#    'Parent',
#    'of',
#    'Prithvi',
#    'Manoj\n',
#    'This',
#    'mail',
#    'is',
#    'a',
#    'small',
#    'appreciation',
#    'for',
#    'the',
#    'efforts',
#    'being',
#    'put',
#    'in',
#    'by',
#    'kindergarten',
#    'teachers',
#    'in',
#    'DPS.\n',
#    '\n',
#    'Our',
#    'son',
#    'Prithvi',
#    'Manoj(UKG',
#    '–K)',
#    'has',
#    'changed',
#    'a',
#    'lot',
#    'from',
#    'his',
#    'first',
#    'day',
#    'in',
#    'Nursery',
#    'till',
#    'today',
#    'and',
#    'all',
#    'these',
#    'changes',
#    'are',
#    'because',
#    'of',
#    'your',
#    'love,',
#    'affection',
#    'and',
#    'care',
#    'you',
#    'provided.',
#    'We',
#    'would',
#    'like',
#    'to',
#    'appreciate',
#    'and',
#    'share',
#    'our',
#    'thanks',
#    'to',
#    'all',
#    'his',
#    'KG',
#    'Teachers',
#    'from',
#    'Nursery',
#    ...],
#   'h1': [],
#   'h2': ['Dedicated To Providing  \nComprehensive Education',
#    'A School That Is " A Class Apart"',
#    'Emphasizing On The Developmental Needs Of The Child']},
#  {'keyword': 'delhi public school justdial',
#   'rank': 3,
#   'title': 'DPS Bangalore School South – Education Excellence!',
#   'description': 'BeSchool | Best WordPress theme for schools. ... care for all kids included. High qualified teachers with licenses. Fresh and tasty food in canteen. Read more\xa0...',
#   'link': 'https://south.dpsbangalore.net/',
#   'doc': ['\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Have',
#    'any',
#    'questions?\n',
#    '+91',
#    '80',
#    '2666',
#    '8582\n',
#    'south@dpsbangalore.net\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Home\n',
#    '\n',
#    'About',
#    'our',
#    'school\n',
#    '\n',
#    'Admission',
#    '&',
#    'Results\n',
#    '\n',
#    '\n',
#    'CBSE',
#    'CURRICULUM\n',
#    '\n',
#    'Admission',
#    'Form',
#    '2019',
#    '–',
#    '2020',
#    'Nursery\n',
#    '\n',
#    'Click',
#    'here',
#    'for',
#    'STD',
#    'XI',
#    'online',
#    'Form',
#    '2019-20\n',
#    '\n',
#    'STD',
#    'XI',
#    'Admission',
#    'Circular',
#    '2019-2020\n',
#    '\n',
#    'Std-XI-Entrance',
#    'Test',
#    'Portion',
#    '2019\n',
#    '\n',
#    'XI',
#    'STD',
#    '–',
#    'Shortlisted',
#    'Candidates\n',
#    '\n',
#    'XI',
#    'STD',
#    '–',
#    'Shortlisted',
#    'Candidates',
#    '2nd',
#    'List\n',
#    '\n',
#    '\n',
#    '\n',
#    'News',
#    '&',
#    'Events\n',
#    '\n',
#    'Contact',
#    'us\n',
#    '\n',
#    'Entrar\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'DPS',
#    'BANGALORE',
#    'SCHOOL',
#    'SOUTH\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'What',
#    'distinguishes\n',
#    'us?\n',
#    '\n',
#    'Our',
#    'mission',
#    'is',
#    'to',
#    'ensure',
#    'that',
#    'every',
#    'child',
#    'is',
#    'equipped',
#    'mentally,',
#    'emotionally,',
#    'socially',
#    'and',
#    'spiritually',
#    'for',
#    'life.',
#    'We',
#    'provide',
#    'a',
#    'quality',
#    'pre-school',
#    'education',
#    'and',
#    'has',
#    'been',
#    'operating',
#    'for',
#    'the',
#    'past',
#    '25',
#    'years.\n',
#    '\n',
#    '\n',
#    'Professional',
#    'medical',
#    'care',
#    'for',
#    'all',
#    'kids',
#    'included.\n',
#    '\n',
#    'High',
#    'qualified',
#    'teachers',
#    'with',
#    'licenses.\n',
#    '\n',
#    'Fresh',
#    'and',
#    'tasty',
#    'food',
#    'in',
#    'canteen.\n',
#    '\n',
#    '\n',
#    'Read',
#    'more\n',
#    '\n',
#    '\n',
#    'Our',
#    'beliefs\n',
#    '\n',
#    '\n',
#    '\n',
#    'We',
#    'belive',
#    'in',
#    'making',
#    'the',
#    'education',
#    'more',
#    'experiential',
#    'learning,',
#    'children',
#    'learn',
#    'from',
#    'experience.',
#    'Our',
#    'belief',
#    'to',
#    'make',
#    'every',
#    'child',
#    'brilliant.\n',
#    '\n',
#    'Read',
#    'more\n',
#    '\n',
#    '\n',
#    'Download',
#    'Registration',
#    'Form\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '2019',
#    '-',
#    '2020',
#    '--',
#    'Nursery\n',
#    '\n',
#    '\n',
#    'What’s',
#    'Happening...?\n',
#    'All',
#    'the',
#    'news',
#    'of',
#    'the',
#    'DPS',
#    'Bangalore',
#    'South',
#    'School',
#    'events',
#    'and',
#    'all',
#    'the',
#    'happenings.',
#    'Welcome',
#    'to',
#    'the',
#    'world',
#    'of',
#    'kids,',
#    'education,',
#    'games,',
#    'and',
#    'achievements.\n',
#    '\n',
#    'September',
#    '30,',
#    '2018\n',
#    'CBSE',
#    'CURRICULUM\n',
#    'Read',
#    'more\n',
#    '\n',
#    '“We',
#    'shall',
#    'walk',
#    'together',
#    'on',
#    'the',
#    'path',
#    'of',
#    'life,',
#    'for',
#    'all',
#    'things',
#    'are',
#    'part',
#    'of',
#    'the',
#    'universe,',
#    'and',
#    'are',
#    'connected',
#    'with',
#    'each',
#    'other',
#    'to',
#    'form',
#    'one',
#    'whole',
#    'unity.”\r\n–',
#    'Maria',
#    'Montessori\n',
#    'To',
#    'educate',
#    'the',
#    'Human',
#    'Potential',
#    'At',
#    'DPS',
#    'Bangalore',
#    'South,',
#    'we',
#    'believe',
#    'in',
#    'creating',
#    'a',
#    'school',
#    'system',
#    'that',
#    'is',
#    'built',
#    'on',
#    'sound',
#    'fundamentals.',
#    'We',
#    'strive',
#    'to',
#    'create',
#    'an',
#    'environment',
#    'that',
#    'would',
#    'empower',
#    'our',
#    'students',
#    'with',
#    'qualities',
#    'of',
#    'intellectual',
#    'competence,',
#    'commitment,',
#    'character,',
#    'discipline,',
#    'diligence',
#    'and',
#    'versatility.',
#    'We',
#    'believe',
#    'in',
#    'providing',
#    'such',
#    'experiences',
#    'to',
#    'your',
#    'child',
#    'that',
#    'would',
#    'inculcate',
#    'a',
#    'keen',
#    'yearning',
#    'to',
#    'develop',
#    'into',
#    'an',
#    'instrument',
#    'of',
#    'social',
#    'progress',
#    'and',
#    'reform,',
#    'for',
#    'through',
#    'education,',
#    'society',
#    'can',
#    'organize',
#    'its',
#    'own',
#    'means',
#    'and',
#    'resources.\n',
#    'In',
#    'the',
#    'words',
#    'of',
#    'Aristotle,',
#    '‘Excellence',
#    'is',
#    'an',
#    'art',
#    'won',
#    'by',
#    'training',
#    'and',
#    'habituation.',
#    'Excellence,',
#    'then',
#    'is',
#    'not',
#    'an',
#    'act,',
#    'but',
#    'a',
#    'habit.’',
#    'The',
#    'exemplary',
#    'performance',
#    'of',
#    'our',
#    'students',
#    'at',
#    'the',
#    'end',
#    'of',
#    'Std.10',
#    '&',
#    '12',
#    'endorse',
#    'the',
#    'certitude',
#    'in',
#    'our',
#    'progress',
#    'towards',
#    'academic',
#    'excellence.',
#    'Emphasis',
#    'is',
#    'also',
#    'laid',
#    'on',
#    'the',
#    'development',
#    'of',
#    'character',
#    'which',
#    'is',
#    'about',
#    'expanding',
#    'social,',
#    'emotional',
#    'competencies',
#    'and',
#    'inner',
#    'temperament',
#    'based',
#    'on',
#    'sound',
#    'values',
#    'to',
#    'act',
#    'in',
#    'a',
#    'consistent',
#    'way',
#    'as',
#    'we',
#    'strive',
#    'to',
#    'build',
#    'other',
#    'competencies—an',
#    'appreciation',
#    'of',
#    'aesthetics,',
#    'physical',
#    'agility',
#    'and',
#    'the',
#    'higher',
#    'intellectual',
#    'domains',
#    'of',
#    'creativity,',
#    'information',
#    'literacy,',
#    'global',
#    'awareness',
#    'and',
#    'cross-cultural',
#    'skills.\n',
#    'Adding',
#    'international',
#    'dimensions',
#    'to',
#    'our',
#    'approach',
#    'towards',
#    'preparing',
#    'our',
#    'children',
#    'to',
#    'become',
#    'global',
#    'citizens,',
#    'we',
#    'have',
#    'partnered',
#    'with',
#    'schools',
#    'in',
#    'the',
#    'United',
#    'Kingdom,',
#    'Italy',
#    'and',
#    'Germany',
#    'to',
#    'execute',
#    'projects',
#    'on',
#    'varied',
#    'themes',
#    'on',
#    'a',
#    'collaborative',
#    'basis.',
#    'The',
#    'International',
#    'School',
#    'Award',
#    'conferred',
#    'by',
#    'the',
#    'British',
#    'Council,',
#    'U.K.',
#    'is',
#    'a',
#    'global',
#    'accreditation',
#    'of',
#    'our',
#    'commitment',
#    'to',
#    'the',
#    'integration',
#    'of',
#    'international',
#    'dimensions',
#    'in',
#    'our',
#    'curriculum.',
#    'DPS',
#    'Bangalore',
#    'South',
#    'is',
#    'a',
#    'proud',
#    'recipient',
#    'of',
#    'the',
#    'ISA',
#    'for',
#    'the',
#    'third',
#    'consecutive',
#    'instance.',
#    'The',
#    'school',
#    'was',
#    'also',
#    'awarded',
#    'the',
#    'Great',
#    'Global',
#    'Project',
#    'Challenge',
#    '2016',
#    'for',
#    'the',
#    'innovative',
#    'project',
#    'on',
#    'Sustainable',
#    'Development',
#    'Goals',
#    'as',
#    'defined',
#    'by',
#    'the',
#    'United',
#    'Nations.\n',
#    'DPS',
#    'Bangalore',
#    'South',
#    'remains',
#    'a',
#    'hub',
#    'of',
#    'activity',
#    'all',
#    'through',
#    'the',
#    'year',
#    'with',
#    'the',
#    'objective',
#    'of',
#    'imparting',
#    'holistic',
#    'education',
#    'and',
#    'instilling',
#    'higher',
#    'values',
#    'that',
#    'are',
#    'crucial',
#    'in',
#    'building',
#    'up',
#    'individual',
#    'and',
#    'collective',
#    'capacity',
#    'and',
#    'in',
#    'strengthening',
#    'the',
#    'cohesiveness',
#    'of',
#    'our',
#    'nation',
#    'beyond',
#    'knowledge',
#    'and',
#    'skills!\n',
#    '\n',
#    'Our',
#    'school',
#    'is',
#    'the\n',
#    'best',
#    'choice\n',
#    'for',
#    'your',
#    'kid\n',
#    'Teaching\n',
#    'A',
#    'teaching',
#    'method',
#    'comprises',
#    'the',
#    'principles',
#    'and',
#    'methods',
#    'used',
#    'by',
#    'teachers',
#    'to',
#    'enable',
#    'student',
#    'learning.',
#    'These',
#    'strategies',
#    'are',
#    'determined',
#    'partly',
#    'on',
#    'subject',
#    'matter',
#    'to',
#    'be',
#    'taught',
#    'and',
#    'partly',
#    'by',
#    'the',
#    'nature',
#    'of',
#    'the',
#    'learner.\n',
#    '\n',
#    '\n',
#    'Creativity\n',
#    'Creative',
#    'education',
#    'is',
#    'when',
#    'students',
#    'are',
#    'able',
#    'to',
#    'use',
#    'imagination',
#    'and',
#    'critical',
#    'thinking',
#    'to',
#    'create',
#    'new',
#    'and',
#    'meaningful',
#    'forms',
#    'of',
#    'ideas',
#    'where',
#    'they',
#    'can',
#    'take',
#    'risks,',
#    'be',
#    'independent',
#    'and',
#    'flexible.\n',
#    '\n',
#    '\n',
#    'Recreation\n',
#    'Recreation',
#    'is',
#    'an',
#    'activity',
#    'of',
#    'leisure,',
#    'leisure',
#    'being',
#    'discretionary',
#    'time.',
#    'The',
#    '"need',
#    'to',
#    'do',
#    'something',
#    'for',
#    'recreation"',
#    'is',
#    'an',
#    'essential',
#    'element',
#    'of',
#    'human',
#    'biology',
#    'and',
#    'psychology.',
#    'Recreational',
#    'activities',
#    'are',
#    'often',
#    'done',
#    'for',
#    'enjoyment,',
#    'amusement,',
#    'or',
#    'pleasure',
#    'and',
#    'are',
#    'considered',
#    'to',
#    'be',
#    '"fun".\n',
#    '\n',
#    '\n',
#    '\n',
#    'Register',
#    'now\n',
#    '\n',
#    'Download',
#    'the',
#    'Registration',
#    'form\n',
#    '\n',
#    'From',
#    'Nursery\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'About',
#    'us\n',
#    '\n',
#    'DPS',
#    'Bangalore',
#    'South',
#    'remains',
#    'a',
#    'hub',
#    'of',
#    'activity',
#    'all',
#    'through',
#    'the',
#    'year',
#    'with',
#    'the',
#    'objective',
#    'of',
#    'imparting',
#    'holistic',
#    'education',
#    'and',
#    'instilling',
#    'higher',
#    'values',
#    'that',
#    'are',
#    'crucial',
#    'in',
#    'building',
#    'up',
#    'individual',
#    'and',
#    'collective',
#    'capacity',
#    'and',
#    'in',
#    'strengthening',
#    'the',
#    'cohesiveness',
#    'of',
#    'our',
#    'nation',
#    'beyond',
#    'knowledge',
#    'and',
#    'skills!\n',
#    '\n',
#    '\n',
#    'Our',
#    'mission\n',
#    '\n',
#    'Our',
#    'mission',
#    'is',
#    'to',
#    'create',
#    'a',
#    'school',
#    'system',
#    'that',
#    'is',
#    'built',
#    'on',
#    'sound',
#    'fundamentals.',
#    'The',
#    'intent',
#    'is',
#    'to',
#    'strive',
#    'towards',
#    'excellence',
#    'by',
#    'responding',
#    'to',
#    'changing',
#    'needs',
#    'and\n',
#    'expectations',
#    'of',
#    'the',
#    'digital',
#    'global',
#    'community.',
#    'The',
#    'focus',
#    'is',
#    'to',
#    'design',
#    'a',
#    'curriculum',
#    'that',
#    'encompasses',
#    'the',
#    'brilliance',
#    'of',
#    'academics,',
#    'skill',
#    'training',
#    'and',
#    'values',
#    'to',
#    'enhance',
#    'intellectual',
#    'competence,',
#    'dynamism,',
#    'versatility',
#    'and',
#    'character.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '©',
#    '2018',
#    'NonVerbals',
#    'Consulting.',
#    'All',
#    'Rights',
#    'Reserved.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    ''],
#   'h1': [],
#   'h2': ['What distinguishesus?',
#    'Our beliefs',
#    'Download Registration Form',
#    '2019 - 2020 -- Nursery',
#    'What’s Happening...?',
#    'Our school is the best choice\n for your kid',
#    'Register now']},
#  {'keyword': 'delhi public school justdial',
#   'rank': 4,
#   'title': 'Delhi Public School Bangalore North - ಮುಖಪುಟ | Facebook',
#   'description': 'Delhi Public School Bangalore North - Survey No 35/1A, Sathnur Village, Bagalur Post, Jalla Hobli, Bangalore, Bangalore, India 562149 - Rated 4.7 based...',
#   'link': 'https://www.facebook.com/DelhiPublicSchoolBangaloreNorth/',
#   'doc': ['\n',
#    'ಇಲ್ಲಿಗೆ',
#    'ಹೋಗು\n',
#    'ಈ',
#    'ಪುಟದ',
#    'ಭಾಗಗಳು\n',
#    'ಪ್ರವೇಶಸಾಧ್ಯತೆಯ',
#    'ನೆರವು\n',
#    'ಈ',
#    'ಪಟ್ಟಿಯನ್ನು',
#    'ತೆರೆಯಲು\n',
#    'alt\n',
#    '+\n',
#    '/\n',
#    'ಅನ್ನು',
#    'ಒತ್ತಿರಿ\n',
#    'ಫೇಸ್\u200dಬುಕ್\u200d\n',
#    'ಇಮೇಲ್',
#    'ಅಥವಾ',
#    'ಫೋನ್:\n',
#    'ಪಾಸ್\u200cವರ್ಡ್\n',
#    'ಖಾತೆಯನ್ನು',
#    'ಮರೆತಿರುವಿರಾ\n',
#    'ಮುಖಪುಟ\n',
#    'ಕುರಿತು\n',
#    'ಈವೆಂಟ್\u200cಗಳು\n',
#    'ವಿಮರ್ಶೆಗಳು\n',
#    'ಫೋಟೋಗಳು\n',
#    'ವೀಡಿಯೊಗಳು\n',
#    'ಪೋಸ್ಟ್\u200cಗಳು\n',
#    'ಸಮುದಾಯ\n',
#    'ಮಾಹಿತಿ',
#    'ಮತ್ತು',
#    'ಜಾಹೀರಾತುಗಳು\n',
#    'ಫೇಸ್ಬುಕ್',
#    'ನಲ್ಲಿ',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'North',
#    'ಕುರಿತು',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'ಲಾಗಿನ್',
#    'ಮಾಡಿ\n',
#    'ಅಥವಾ\n',
#    'ಹೊಸ',
#    'ಖಾತೆಯನ್ನು',
#    'ರಚಿಸಿ\n',
#    'ಫೇಸ್ಬುಕ್',
#    'ನಲ್ಲಿ',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'North',
#    'ಕುರಿತು',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'ಲಾಗಿನ್',
#    'ಮಾಡಿ\n',
#    'ಖಾತೆಯನ್ನು',
#    'ಮರೆತಿರುವಿರಾ\n',
#    'ಅಥವಾ\n',
#    'ಹೊಸ',
#    'ಖಾತೆಯನ್ನು',
#    'ರಚಿಸಿ\n',
#    'ಈಗ',
#    'ಬೇಡ\n',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'North\n',
#    'ಕಲಿಯಂಗಳದ',
#    'ಕಟ್ಟಡ',
#    'ನಲ್ಲಿ\xa0Bangalore,',
#    'India\n',
#    '4.7\n',
#    '4.7',
#    'out',
#    'of',
#    '5',
#    'stars.\n',
#    'ಇದೀಗ',
#    'ಮುಚ್ಚಲಾಗಿದೆ\n',
#    'ಸಮುದಾಯ\n',
#    'ಎಲ್ಲವನ್ನು',
#    'ನೋಡಿ\n',
#    '2,897',
#    'ಜನರು',
#    'ಇದನ್ನು',
#    'ಇಷ್ಟಪಟ್ಟಿದ್ದಾರೆ\n',
#    '3,081',
#    'ಜನರು',
#    'ಇದನ್ನು',
#    'ಅನುಸರಿಸುತ್ತಿದ್ದಾರೆ\n',
#    'ಕುರಿತು\n',
#    'ಎಲ್ಲವನ್ನೂ',
#    'ನೋಡಿ\n',
#    'Survey',
#    'No',
#    '35/1A,',
#    'Sathnur',
#    'Village,',
#    'Bagalur',
#    'Post,',
#    'Jalla',
#    'Hobli,',
#    'Bangalore',
#    '(20.42',
#    'km)\n',
#    'Bangalore,',
#    'India',
#    '562149\n',
#    'ದಿಕ್ಕುಗಳನ್ನು',
#    'ಪಡೆಯಿರಿ\n',
#    '080',
#    '2972',
#    '4867\n',
#    'north.dpsbangalore.edu.in\n',
#    'ಕಲಿಯಂಗಳದ',
#    'ಕಟ್ಟಡ\n',
#    '·\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    '·\n',
#    'ಖಾಸಗಿ',
#    'ಶಾಲೆ\n',
#    'ನಾಳೆ',
#    'ತೆರೆಯುತ್ತದೆ\n',
#    'ಇದೀಗ',
#    'ಮುಚ್ಚಲಾಗಿದೆ\n',
#    'ಪುಟ',
#    'ಪಾರದರ್ಶಕತೆ\n',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'ಪುಟದ',
#    'ಉದ್ದೇಶವನ್ನು',
#    'ಚೆನ್ನಾಗಿ',
#    'ಅರ್ಥಮಾಡಿಕೊಳ್ಳಲು',
#    'ಸಹಾಯ',
#    'ಮಾಡಲು',
#    'Facebook',
#    'ಮಾಹಿತಿಯನ್ನು',
#    'ತೋರಿಸುತ್ತಿದೆ.',
#    'ವಿಷಯವನ್ನು',
#    'ನಿರ್ವಹಿಸುವ',
#    'ಮತ್ತು',
#    'ಪೋಸ್ಟ್',
#    'ಮಾಡುವ',
#    'ಜನರು',
#    'ತೆಗೆದುಕೊಂಡ',
#    'ಕ್ರಮಗಳನ್ನು',
#    'ನೋಡಿ.\n',
#    'Page',
#    'created',
#    '-',
#    'ಜುಲೈ',
#    '1,',
#    '2016\n',
#    'ಜನ\n',
#    '2,897\n',
#    'ಇಷ್ಟಗಳು\n',
#    '492\n',
#    '\n',
#    'ಭೇಟಿಗಳು\n',
#    'ಸಂಬಂಧಿಸಿದ',
#    'ಪುಟಗಳು\n',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'South\n',
#    'ಸಮುದಾಯ',
#    'ಕಾಲೇಜು\n',
#    'GREEN',
#    'DOT',
#    'Montessori',
#    'School\n',
#    'ಶಾಲೆ\n',
#    'National',
#    'Public',
#    'School\n',
#    'ಶಾಲೆ\n',
#    'Jain',
#    'public',
#    'school',
#    'bangalore\n',
#    'ಶಾಲೆ\n',
#    'Drishti',
#    'Art',
#    'Centre\n',
#    'ಕಲೆ',
#    'ಮತ್ತು',
#    'ನಲಿವು\n',
#    'Manasa',
#    'School\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'East\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'CHRIST',
#    'SCHOOL\n',
#    'ಸಮುದಾಯ',
#    'ಕಾಲೇಜು\n',
#    'Bangalore',
#    'International',
#    'Public',
#    'School\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'Delhi',
#    'Public',
#    'School,',
#    'Electronic',
#    'City\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'Ryan',
#    'International',
#    'School,',
#    'Kundalahali\n',
#    'ಶಿಕ್ಷಣ\n',
#    'Edify',
#    'School',
#    'Electronic',
#    'City\n',
#    'ಶಿಕ್ಷಣ\n',
#    'Trio',
#    'World',
#    'Academy\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'Seshadripuram',
#    'First',
#    'Grade',
#    'College\n',
#    'ಕಲಿಯಂಗಳದ',
#    'ಕಟ್ಟಡ\n',
#    'School',
#    'Of',
#    'India\n',
#    'ಕಲಿಯಂಗಳದ',
#    'ಕಟ್ಟಡ\n',
#    'The',
#    'HDFC',
#    'School',
#    'Bengaluru\n',
#    'ಶಾಲೆ\n',
#    'Utpala\n',
#    'ಮಹಿಳಾ',
#    'ಉಡುಗೆ',
#    'ಅಂಗಡಿ\n',
#    'GEAR',
#    'Foundation\n',
#    'ಪ್ರೌಢ',
#    'ಶಾಲೆ\n',
#    'Clarence',
#    'High',
#    'School,',
#    'Bangalore\n',
#    'ಪ್ರಾಥಮಿಕ',
#    'ಶಾಲೆ\n',
#    'Harvest',
#    'International',
#    'School\n',
#    'ಕಲಿಯಂಗಳದ',
#    'ಕಟ್ಟಡ\n',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'triangle-down\n',
#    'ಈ',
#    'ಪುಟದ',
#    'ಮೂಲಕ',
#    'ಇಷ್ಟಪಟ್ಟ',
#    'ಪುಟಗಳು\n',
#    'ATL',
#    'at',
#    'DPS',
#    'Bangalore',
#    'North\n',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'North',
#    'Sports',
#    'Day\n',
#    'DPS',
#    'Bangalore',
#    'North',
#    'HABBA',
#    '2012\n',
#    'DNMUN\n',
#    'DPS',
#    'Bangalore',
#    'North',
#    'Habba\n',
#    'ಸ್ಥಳಗಳು\n',
#    'Bangalore,',
#    'India\n',
#    'ಖಾಸಗಿ',
#    'ಶಾಲೆ\n',
#    'Delhi',
#    'Public',
#    'School',
#    'Bangalore',
#    'North\n',
#    'ಕನ್ನಡ\n',
#    '·\n',
#    'اردو\n',
#    '·\n',
#    'मराठी\n',
#    '·\n',
#    'తెలుగు\n',
#    '·\n',
#    'English',
#    '(UK)\n',
#    'ಗೌಪ್ಯತೆ\n',
#    '·\n',
#    'ನಿಯಮಗಳು\n',
#    '·\n',
#    'ಜಾಹಿರಾತುಗಳು\n',
#    '·\n',
#    'Ad',
#    'Choices\n',
#    '·\n',
#    'ಕುಕೀಗಳು\n',
#    '·\n',
#    'ಇನ್ನಷ್ಟು\n',
#    'Facebook',
#    '©',
#    '2019\n',
#    'ಶಿಫಾರಸುಗಳು',
#    'ಮತ್ತು',
#    'ವಿಮರ್ಶೆಗಳು\n',
#    '14',
#    'ಜನರು',
#    'ಶಿಫಾರಸು',
#    'ಮಾಡಿದ್ದಾರೆ\n',
#    'it',
#    'is',
#    'the',
#    'best',
#    'school',
#    'ever!!',
#    'love',
#    'it',
#    '!!',
#    'it',
#    'is',
#    'very',
#    'big',
#    'and',
#    'just',
#    'love',
#    'the',
#    'faculty',
#    'of',
#    'teachers',
#    'teaching',
#    'here',
#    '!!😊👌👍\n',
#    '6',
#    'ಫೆಬ್ರವರಿ\n',
#    'One',
#    'of',
#    'the',
#    'best',
#    'CBSE',
#    'schools',
#    'in',
#    'Bangalore',
#    'north,',
#    'great',
#    'learning',
#    'atmosphere,',
#    'well',
#    'trained',
#    'teachers.',
#    'A\n',
#    '...\n',
#    'mple',
#    'parking',
#    'space,',
#    'good',
#    'approach',
#    'road\n',
#    '\n',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'ಡಿಸೆಂಬರ್',
#    '15,',
#    '2018\n',
#    'ಕನ್ನಡವನ್ನು',
#    'ಓದಲು',
#    'ವಿದ್ಯಾರ್ಥಿಗಳಿಗೆ',
#    'ಆಯ್ಕೆ',
#    'ಮಾಡಿದಕ್ಕೆ',
#    'ಈ',
#    '೧\n',
#    'ಸರ್ಕಾರದ',
#    'ಆದೇಶವನ್ನು',
#    'ಪಾಲಿಸದ',
#    'ನೀವು',
#    'ಇನ್ನು',
#    'ವಿದ್ಯಾರ್ಥಿಗ\n',
#    '...\n',
#    'ಳ',
#    'ಜೀವನವನ್ನು',
#    'ಹೇಗೆ',
#    'ನಿರ್ಮಿಸುತ್ತಿರ\n',
#    'ಕರ್ನಾಟಕದಲ್ಲಿ',
#    'ಕನ್ನಡಿಗ',
#    'ತನ್ನ',
#    'ಭಾಷೆ',
#    'ಕಲಿಯಲು',
#    'ಆಯ್ಕೆ',
#    'ಬೇಕ\n',
#    'ನೀವು',
#    'ಎಲ್ಲವನ್ನೂ',
#    'ಪರಭಾಷೆಯಲ್ಲಿ',
#    'ಹೇಳಿ',
#    'ಕೋಟ್ಟರು',
#    'ನೋವದಾಗ',
#    'ಅಮ್ಮ',
#    'ಎನ್ನುವ',
#    'ಭಾಷೆ',
#    'ಕನ್ನಡ',
#    'ಮಾತ್ರ\n',
#    'ಕನ್ನಡ',
#    'ಉಳಿಸಿ',
#    'ಕನ್ನಡ',
#    'ಬೆಳೆಸಿ\n',
#    '\n',
#    'ಇನ್ನಷ್ಟು',
#    'ನೋಡಿ\n',
#    'ಮಾರ್ಚ್',
#    '8,',
#    '2018\n',
#    'ಎಲ್ಲವನ್ನೂ',
#    'ವೀಕ್ಷಿಸಿ\n',
#    'ಫೋಟೋಗಳು\n',
#    'ಎಲ್ಲವನ್ನೂ',
#    'ನೋಡಿ\n',
#    'ವೀಡಿಯೋಗಳು\n',
#    '130\n',
#    '38\n',
#    'Art',
#    'with',
#    'Purpose',
#    '2018\n',
#    '82\n',
#    '119\n',
#    '40\n',
#    'ಎಲ್ಲವನ್ನೂ',
#    'ನೋಡಿರಿ\n',
#    'ಇನ್ನಷ್ಟು',
#    'ವೀಕ್ಷಿಸಿ\n',
#    '\n',
#    '\n',
#    ''],
#   'h1': ['Delhi Public School Bangalore Northಕಲಿಯಂಗಳದ ಕಟ್ಟಡ ನಲ್ಲಿ\xa0Bangalore, India'],
#   'h2': []},
#  {'keyword': 'delhi public school justdial',
#   'rank': 5,
#   'title': 'Delhi Public School Society',
#   'description': "Injunction Order of Hon'ble Supreme Court of India, Dated 24 July, 2018 Click here. Beware of fake / unauthorized / illegal schools operating under the name of\xa0...",
#   'link': 'http://www.dpsfamily.org/',
#   'doc': ['\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Injunction',
#    'Order',
#    'of',
#    'Honâ\x80\x99ble',
#    'Supreme',
#    'Court',
#    'of',
#    'India,',
#    'Dated',
#    '24',
#    'July,',
#    '2018',
#    'Click',
#    'here.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beware',
#    'of',
#    'fake',
#    '/',
#    'unauthorized',
#    '/',
#    'illegal',
#    'schools',
#    'operating',
#    'under',
#    'the',
#    'name',
#    'of',
#    'Delhi',
#    'Public',
#    'Schools',
#    '/',
#    'DPS.',
#    '',
#    'For',
#    'court',
#    'order(s)\n',
#    'click',
#    'here.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'SCHOOLS\n',
#    '\n',
#    'DPS',
#    'SOCIETY\n',
#    '\n',
#    '\n',
#    'HRDC\n',
#    '\n',
#    'HOME\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Genesis\n',
#    '\n',
#    'Members',
#    'Of',
#    'DPS',
#    'Society\n',
#    '\n',
#    'Mission',
#    'Statement\n',
#    '\n',
#    'Spanning',
#    '60',
#    'years\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'The',
#    'DPS',
#    'Society',
#    'is',
#    'a',
#    'non-profit,',
#    'non-proprietary,',
#    'private,',
#    'educational',
#    'organization.',
#    'This',
#    'Global',
#    'Network',
#    'of',
#    'over',
#    '200',
#    'English',
#    'medium,',
#    'co-educational,',
#    'secular',
#    'schools',
#    'provides',
#    'education',
#    'from',
#    'Pre-Nursery/Nursery',
#    'to',
#    'Class',
#    'XII.',
#    'The',
#    'DPS',
#    'Family',
#    'â\x80\x93',
#    'with',
#    'its',
#    'transcontinental',
#    'identity,',
#    'is',
#    'not',
#    'merely',
#    'a',
#    'list',
#    'of',
#    'institutions,',
#    'persons',
#    'or',
#    'facts;',
#    'it',
#    'is',
#    'a',
#    'network',
#    'of',
#    'values,',
#    'systems',
#    'and',
#    'relationships.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'News',
#    '&',
#    'Events\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Photo',
#    'Gallery\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'current\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Archive\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '<\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'The',
#    'DPS',
#    'FAMILY',
#    ':\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Web',
#    'Mail\n',
#    '\n',
#    '\n',
#    '\n',
#    'Accomplishments:',
#    'Scholastic\n',
#    '\n',
#    '\n',
#    '\n',
#    'Accomplishments:',
#    'Games',
#    '&',
#    'Sports\n',
#    '\n',
#    '\n',
#    '\n',
#    'Accomplishments:',
#    'Cultural\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'We',
#    'feel',
#    'proud',
#    'to',
#    'inform',
#    'that',
#    'Shri',
#    'V.K.',
#    'Shunglu,',
#    'Chairman',
#    'of',
#    'The',
#    'DPS',
#    'Society,',
#    'has',
#    'been',
#    'honoured',
#    'with',
#    'the',
#    'prestigious',
#    'PADMA',
#    'BHUSHAN',
#    'award',
#    'this',
#    'year.\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Quick',
#    'Links\n',
#    '\n',
#    '\n',
#    'Job',
#    'Opportunities\n',
#    '\n',
#    '\n',
#    'Contact',
#    'Us\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Copyright',
#    'Â©',
#    'The',
#    'Delhi',
#    'Public',
#    'School',
#    'Society',
#    '',
#    '2010\n',
#    '\n',
#    '\n',
#    ''],
#   'h1': [],
#   'h2': []}]

# %% [markdown]
# # Main function

# %%
def scrape_google(search_term, number_results, language_code):
    try:
        keyword, html = fetch_results(search_term, number_results, language_code)
        results = parse_results(html, keyword)
        return results
    except AssertionError:
        raise Exception("Incorrect arguments parsed to function")
    except requests.HTTPError:
        raise Exception("You appear to have been blocked by Google")
    except requests.RequestException:
        raise Exception("Appears to be an issue with your connection")


# if __name__ == '__main__':
# #     keywords = ['edmund martin', 'python', 'google scraping']

# destination = input('What is your keyword?')
# x = destination
# links =[]
# # keywords = [x+" tourism", x+" travel", x+" vaccation"]
# data = []
# # for keyword in x:

keyword = input('What is your keyword?')
results = int(input('How Many search results would you want to fetch : '))
data = []

try:
    results = scrape_google(keyword, results, "en")
    for result in results:
        data.append(result)
        print(len(results))
except Exception as e:
    print(e)
finally:
    time.sleep(1)
# Out:
# What is your keyword?gmat
# How Many search results would you want to fetch2
# https://collegedunia.com/exams/gmat
# https://studyabroad.shiksha.com/exams/gmat
# 2
# 2

# %%
data
# Out:
# [{'keyword': 'gmat',
#   'rank': 1,
#   'title': 'GMAT 2019 Registration, Eligibility, Exam Date, Pattern, Syllabus, Fee',
#   'description': 'GMAT Registration is open throughout the year. The provision of appearing for the test depends on the availability of Exam Dates and Exam Centers. GMAT\xa0...',
#   'link': 'https://collegedunia.com/exams/gmat',
#   'doc': ['Useful',
#    'Links\n',
#    'News\n',
#    'top',
#    'links\n',
#    'top',
#    'universities\n',
#    'top',
#    'colleges\n',
#    'top',
#    'exams\n',
#    'latest',
#    'news\n',
#    'top',
#    'courses\n',
#    'filter',
#    'your',
#    'search\n',
#    'all\n',
#    'colleges\n',
#    'exam\n',
#    'news\n',
#    'trending',
#    'Searches\n',
#    'Upcoming',
#    'Exams\n',
#    '"IIT"',
#    'in',
#    'Colleges\n',
#    '"CAT"',
#    'in',
#    'Exams\n',
#    '"Cat',
#    'Cutoff"',
#    'in',
#    'News\n',
#    '"MBA',
#    'Colleges"',
#    'in',
#    'Delhi/NCR\n',
#    '"MCA',
#    'Colleges"',
#    'in',
#    'Delhi/NCR\n',
#    'top',
#    'universities\n',
#    'top',
#    'courses\n',
#    'colleges\n',
#    'exams\n',
#    'REVIEWS\n',
#    'news\n',
#    'ADMISSION',
#    '2019\n',
#    'Write',
#    'a',
#    'Review\n',
#    'TOP',
#    'COUPONS\n',
#    'New\n',
#    'login\n',
#    'download\n',
#    "we're\n",
#    'on',
#    'mobile',
#    'too\n',
#    'get',
#    'collegedunia',
#    'app',
#    'for\n',
#    '10x',
#    'faster',
#    'experience\n',
#    'get',
#    'app',
#    'link',
#    'on',
#    'your',
#    'mobile\n',
#    '+91\n',
#    'Get',
#    'App',
#    'Link\n',
#    'Toggle',
#    'navigation\n',
#    'home\n',
#    'Govt',
#    'Exams\n',
#    '^\n',
#    'Study',
#    'Abroad\n',
#    '^\n',
#    'COMMERCE\n',
#    '^\n',
#    'ENGINEERING\n',
#    '^\n',
#    'MEDICAL\n',
#    '^\n',
#    'MANAGEMENT\n',
#    '^\n',
#    'More\n',
#    '^\n',
#    '\n',
#    'Exams\n',
#    '>\n',
#    'GMAT\n',
#    'GMAT',
#    '2019\n',
#    'ONLINE',
#    'TEST\n',
#    'GRADUATE',
#    'MANAGEMENT',
#    'ADMISSION',
#    'TEST\n',
#    'MANAGEMENT',
#    'ENTRANCE',
#    'EXAMINATIONS\n',
#    'MBA/PGDM',
#    'ENTRANCE',
#    'EXAMINATIONS\n',
#    'GET',
#    'FREE',
#    'COUNSELLING\n',
#    'UPCOMING',
#    'EXAMS\n',
#    'CUSAT-CAT',
#    '2019\n',
#    'TOEFL',
#    '2019\n',
#    'Overview\n',
#    'application',
#    '&',
#    'registration\n',
#    'EXAM',
#    'DATES\n',
#    'ELIGIBILITY\n',
#    'EXAM',
#    'CENTERS\n',
#    'pattern',
#    '&',
#    'syllabus\n',
#    'SYLLABUS\n',
#    'preparation',
#    'tips\n',
#    'practice',
#    'papers\n',
#    'result',
#    '&',
#    'counselling\n',
#    'participating',
#    'colleges\n',
#    'news\n',
#    'cutoff\n',
#    'Table',
#    'of',
#    'Content\n',
#    'WANT',
#    'TO',
#    'KNOW',
#    'MORE?\n',
#    'ASK',
#    'QUESTIONS',
#    'TO',
#    'OUR',
#    'EXPERTS\n',
#    '×\n',
#    'DO',
#    'YOU',
#    'HAVE',
#    'ANY',
#    'DOUBT',
#    '?\n',
#    'Our',
#    'experts',
#    'will',
#    'be',
#    'available',
#    'for',
#    'you',
#    'and',
#    'will',
#    'help',
#    'you',
#    'in',
#    'solving',
#    'all',
#    'your',
#    'issues\n',
#    'SUBMIT\n',
#    'GMAT',
#    '2019',
#    'Registration,',
#    'Exam',
#    'Date,',
#    'Pattern,',
#    'Syllabus\n',
#    'Updated',
#    'On',
#    '-',
#    'April',
#    '1st',
#    '2019',
#    '',
#    'by\n',
#    'SHIVANSHI',
#    'RATHAUR\n',
#    'Graduate',
#    'Management',
#    'Admission',
#    'Test',
#    '(GMAT)\n',
#    'is',
#    'conducted',
#    'by\n',
#    'GMAC\n',
#    'for',
#    'admission',
#    'to',
#    'nearly',
#    '7,100\n',
#    'management',
#    'courses\n',
#    'in',
#    'various',
#    'Business',
#    'Schools',
#    'around',
#    'the',
#    'world.',
#    'GMAT',
#    'exam',
#    'is\xa0conducted\n',
#    'across',
#    '600',
#    'centers',
#    'in',
#    '114',
#    'countries\n',
#    'around',
#    'the',
#    'world.\n',
#    'GMAT',
#    '2019\xa0Exam',
#    'Dates\n',
#    'GMAT',
#    'Syllabus',
#    '2019\n',
#    'GMAT',
#    'in',
#    'German\n',
#    'GMAT',
#    'in',
#    'French\n',
#    'GMAT',
#    'in',
#    'Spanish\n',
#    'GMAT',
#    'Registration\n',
#    '\n',
#    'is',
#    'open\xa0throughout',
#    'the',
#    'year.\xa0The',
#    'provision',
#    'of',
#    'appearing',
#    'for',
#    'the\xa0test',
#    'depends',
#    'on',
#    'the',
#    'availability',
#    'of',
#    'Exam',
#    'Dates',
#    'and',
#    'Exam',
#    'Centers.\xa0GMAT',
#    'Application',
#    'Fee\n',
#    'is',
#    'USD',
#    '250.\n',
#    'More',
#    'than\n',
#    '200,000\n',
#    'candidates',
#    'take',
#    'GMAT',
#    'each',
#    'year.\n',
#    'GMAT',
#    'is',
#    'a\n',
#    'computer',
#    'adaptive',
#    'test\n',
#    'with\xa0a',
#    'total',
#    'of\n',
#    '80\xa0questions,\n',
#    'that',
#    'must',
#    'be',
#    'completed',
#    'in\n',
#    '3\xa0hours',
#    '7',
#    'minutes\n',
#    '.\n',
#    'There',
#    'are\n',
#    '4\xa0sections\n',
#    'in',
#    'GMAT',
#    'such',
#    'as\xa0Analytical',
#    'Writing',
#    'Assessment,',
#    'Integrated',
#    'Reasoning,',
#    'Quantitative',
#    'and',
#    'Verbal',
#    'Section.\n',
#    'Read',
#    'complete\n',
#    '\n',
#    'GMAT',
#    'Exam',
#    'Pattern\n',
#    'The',
#    'average',
#    'test',
#    'score',
#    'accepted',
#    'by',
#    'MBA',
#    'college',
#    'abroad',
#    'lies',
#    'between\n',
#    '650-790\n',
#    '.\n',
#    'Check',
#    'GMAT',
#    '2019',
#    'Practice',
#    'papers\n',
#    'GMAT',
#    'Score\n',
#    'and',
#    'Percentile',
#    'Rankings\n',
#    'are',
#    'calculated',
#    'for',
#    'all',
#    'the',
#    'four',
#    'sections.',
#    'The',
#    'Score',
#    'is',
#    'released\xa0approximately',
#    'after\n',
#    'three',
#    'weeks',
#    'of',
#    'test.\n',
#    'GMAT',
#    '2019:',
#    'Latest',
#    'Updates\n',
#    'GMAT',
#    'can',
#    'be',
#    'taken\xa0up',
#    'to\n',
#    'five',
#    'times',
#    'over',
#    'a',
#    'period',
#    'of',
#    '12',
#    'months\n',
#    ',',
#    'with',
#    'each',
#    'test',
#    'being',
#    'atleast',
#    '16',
#    'days',
#    'apart.\n',
#    'GMAC',
#    'has',
#    'recently',
#    'launched',
#    '‘\n',
#    'Select',
#    'Section',
#    'Order’\n',
#    '.',
#    'This',
#    'feauture',
#    'allows\xa0candidates',
#    'the',
#    'flexibility',
#    'to',
#    'customize',
#    'their',
#    'GMAT',
#    'experience',
#    'by',
#    'choosing',
#    'the',
#    'section',
#    'order',
#    'in',
#    'which',
#    'they',
#    'feel',
#    'most',
#    'comfortable',
#    'taking',
#    'the',
#    'exam.\n',
#    'GMAC',
#    'has\n',
#    'eliminated',
#    'profile-update',
#    'questions\n',
#    'on',
#    'test',
#    'day.\n',
#    'GMAT',
#    '2019',
#    'Highlights\n',
#    'Exam',
#    'Name\n',
#    'Graduate',
#    'Management',
#    'Admission',
#    'Test\n',
#    'Short-',
#    'Form\n',
#    'GMAT\n',
#    'Official',
#    'website\n',
#    'www.mba.com\n',
#    'Level',
#    'of',
#    'the',
#    'exam\n',
#    'International\n',
#    'Organising',
#    'Body\n',
#    'Graduate',
#    'Management',
#    'Admission',
#    'Council\n',
#    'Mode',
#    'of',
#    'exam\n',
#    'Computer',
#    'based\n',
#    'GMAT',
#    'fee\n',
#    'US',
#    '$250\n',
#    'Score',
#    'Range\n',
#    '200-800',
#    'overall\n',
#    'GMAT',
#    'Test',
#    'Centers\n',
#    '600',
#    'across',
#    'the',
#    'world\n',
#    'GMAT',
#    'Helpline\n',
#    '+852-3077-4926',
#    '|\xa0+91',
#    '120-439-7830(India)\n',
#    'What',
#    'is',
#    'GMAT?\n',
#    'GMAT',
#    'is',
#    'an',
#    'online',
#    'test',
#    'conducted',
#    'for',
#    'admissions',
#    'into',
#    'various',
#    'management',
#    'programmes',
#    'offered',
#    'by',
#    'B-Schools',
#    'all',
#    'around',
#    'the',
#    'globe.',
#    'The',
#    'exam',
#    'tests',
#    'a',
#    'candidate',
#    '’s',
#    'analytical,',
#    'writing,',
#    'quantitative,',
#    'verbal,',
#    'and',
#    'reading',
#    'skills',
#    'in\xa0English',
#    'to',
#    'be',
#    'used',
#    'for',
#    'the\xa0stated',
#    'purpose.\n',
#    'Why',
#    'Apply',
#    'for',
#    'GMAT?\n',
#    'GMAT',
#    'offers',
#    'the',
#    'following\xa0benefits:\n',
#    'Unmatched',
#    'Expertise-\n',
#    'Backed',
#    'by',
#    'Decades',
#    'of',
#    'Peer-Reviewed',
#    'Research\n',
#    'Relevant-\n',
#    'For',
#    'You,',
#    'Your',
#    'Candidates,',
#    'and',
#    'Their',
#    'Futures\n',
#    'Consistent-\n',
#    'Over',
#    'Time',
#    'and',
#    'Across',
#    'the',
#    'Globe\n',
#    'Precise-\n',
#    'For',
#    'Accurate',
#    'Student-to-Program',
#    'Matches\n',
#    'Secure-\n',
#    'Using',
#    'State-of-the-Art',
#    'Technology\n',
#    'Reliable',
#    'and',
#    'Available\n',
#    'Around',
#    'the',
#    'World\n',
#    'What',
#    'is',
#    'a',
#    'computer-adaptive',
#    'test?\n',
#    'A',
#    'computer-adaptive',
#    'test',
#    'is',
#    'the',
#    'one',
#    'that',
#    'adjusts',
#    'to',
#    'the',
#    'level',
#    'of',
#    'a',
#    'candidate’s',
#    'ability.\xa0At',
#    'the',
#    'beginning',
#    'of',
#    'the',
#    'test,',
#    'a',
#    'candidate',
#    'is',
#    'presented',
#    'with',
#    'questions',
#    'of',
#    'average',
#    'difficulty.\xa0The',
#    'difficulty',
#    'level',
#    'of',
#    'the',
#    'upcoming',
#    'questions\xa0increases',
#    'or',
#    'decreases',
#    'based',
#    'on',
#    'the',
#    'candidates',
#    'performances',
#    'on',
#    'previous',
#    'questions.',
#    'If',
#    'a',
#    'candidate',
#    'answers',
#    'the',
#    'questions',
#    'incorrectly,',
#    'the',
#    'difficulty',
#    'level',
#    'decreases.',
#    'If',
#    'a',
#    'candidate',
#    'is',
#    'getting',
#    'most',
#    'of',
#    'the',
#    'questions',
#    'correct,',
#    'then',
#    'the',
#    'difficulty',
#    'level',
#    'of',
#    'the',
#    'next',
#    'questions',
#    'increases.',
#    'This',
#    'process',
#    'continues',
#    'until',
#    'all',
#    'the',
#    'questions',
#    'in',
#    'every',
#    'section',
#    'is',
#    'attempted.\n',
#    'Since',
#    'the',
#    'next',
#    'question',
#    'is',
#    'generated',
#    'based',
#    'on',
#    'a',
#    'candidate’s',
#    'performance',
#    'in',
#    'current',
#    'question(s),',
#    'one',
#    'cannot',
#    'revisit',
#    'any',
#    'previous',
#    'question(s).',
#    'It',
#    'is',
#    'mandatory',
#    'to\xa0answer',
#    'every',
#    'question',
#    'in',
#    'order',
#    'to',
#    'proceed',
#    'to',
#    'the',
#    'next',
#    'question.\n',
#    'What',
#    'is\xa0Executive',
#    'Assessment',
#    'Exam?\n',
#    'GMAC',
#    'has',
#    'recently',
#    'introduced',
#    'a',
#    'new\n',
#    'Mini',
#    'GMAT',
#    'called',
#    'Executive',
#    'Assessment',
#    'Exam\n',
#    'for',
#    'Executive',
#    'MBA',
#    'course.',
#    'This',
#    'exam',
#    'is',
#    'designed',
#    'for',
#    'candidates',
#    'willing',
#    'to',
#    'pursue',
#    'E-MBA.\xa0The',
#    'exam',
#    'is',
#    'of',
#    'considerably',
#    'shorter',
#    'duration',
#    'than',
#    'the',
#    'regular',
#    'GMAT.',
#    'The',
#    'test',
#    'is',
#    'formulated',
#    'to',
#    'examine',
#    'analytical',
#    'and',
#    'logical',
#    'thinking',
#    'abilities',
#    'of',
#    'the',
#    'test',
#    'takers,',
#    'It',
#    'is',
#    'intended\xa0to',
#    'judge\xa0suitability',
#    'of',
#    'the',
#    'candidates',
#    'for',
#    'the',
#    'E-MBA',
#    'course.\n',
#    'How',
#    'much',
#    'does',
#    'it',
#    'cost',
#    'to',
#    'take',
#    'GMAT?\n',
#    'Taking',
#    'a',
#    'GMAT',
#    'exam',
#    'costs\n',
#    'US',
#    '$250\n',
#    'worldwide.',
#    'If',
#    'any',
#    'candidate\xa0wishes',
#    'to',
#    'reschedule',
#    'the',
#    'exam,',
#    'they',
#    'need',
#    'to',
#    'pay\xa0an',
#    'additional',
#    'fee',
#    'of\n',
#    'US',
#    '$50.\n',
#    'The',
#    'GMAT',
#    'Cancellation',
#    'Fee',
#    'is\n',
#    'US',
#    '$80.\n',
#    'What',
#    'is',
#    'the',
#    'difference',
#    'between',
#    'GMAT',
#    'and',
#    'GRE?\n',
#    'GMAT\xa0is',
#    'the',
#    'standardized',
#    'test',
#    'for',
#    'top',
#    'Business',
#    'schools',
#    'all',
#    'across',
#    'the',
#    'world.',
#    'Similar',
#    'to\xa0GRE,',
#    'the',
#    'exam',
#    'consists',
#    'of',
#    'a',
#    'Verbal',
#    'and',
#    'Quantitative',
#    'section.\n',
#    'Unlike\xa0GRE,',
#    'the',
#    'two',
#    'sections',
#    'are',
#    'combined',
#    'to',
#    'give',
#    'a\n',
#    'composite',
#    'score',
#    'of',
#    '800\n',
#    '.\n',
#    'GMAT\xa0cannot',
#    'be',
#    'used',
#    'in',
#    'place',
#    'of',
#    'the\xa0GRE,',
#    'so',
#    'unless',
#    'a',
#    'candidate',
#    'is',
#    'sure',
#    'about',
#    'making',
#    'his',
#    'way\xa0to',
#    'a',
#    'business',
#    'school,',
#    'they',
#    'are',
#    'adviced',
#    'not',
#    'to',
#    'take',
#    'GMAT',
#    'Exam.\n',
#    'GMAT',
#    'is',
#    'a',
#    'test',
#    'recognized',
#    'by',
#    'AICTE',
#    'for',
#    'PGDM',
#    'and',
#    'PGCM',
#    'courses',
#    'conducted',
#    'by',
#    'the',
#    'respective',
#    'State',
#    'Governments',
#    'for',
#    'all',
#    'institutions',
#    'other',
#    'than',
#    'minority',
#    'institutions',
#    'across',
#    'India.',
#    'GRE',
#    'is',
#    'not.\n',
#    'What',
#    'is\xa0percentile',
#    'v/s',
#    'marks',
#    'assessment\xa0in',
#    'GMAT?\n',
#    'The',
#    'below',
#    'table',
#    'will',
#    'help',
#    'you',
#    'learn',
#    'about',
#    'GMAT',
#    'marks',
#    'vs',
#    'percentile:\n',
#    'PERCENTILE\n',
#    'SCORE\n',
#    'PERCENTILE\n',
#    'SCORE\n',
#    '99%\n',
#    '760-800\n',
#    '33%\n',
#    '520\n',
#    '98%\n',
#    '750\n',
#    '31%\n',
#    '510\n',
#    '97%\n',
#    '740\n',
#    '28%\n',
#    '500\n',
#    '96%\n',
#    '730\n',
#    '26%\n',
#    '490\n',
#    '94%\n',
#    '720\n',
#    '24%\n',
#    '480\n',
#    '91%\n',
#    '710\n',
#    '22%\n',
#    '470\n',
#    '88%\n',
#    '700\n',
#    '19%\n',
#    '460\n',
#    '86%\n',
#    '690\n',
#    '18%\n',
#    '450\n',
#    '83%\n',
#    '680\n',
#    '16%\n',
#    '440\n',
#    '81%\n',
#    '670\n',
#    '15%\n',
#    '430\n',
#    '78%\n',
#    '660\n',
#    '14%\n',
#    '420\n',
#    '75%\n',
#    '650\n',
#    '13%\n',
#    '410\n',
#    '70%\n',
#    '640\n',
#    '11%\n',
#    '400\n',
#    '68%\n',
#    '630\n',
#    '10%\n',
#    '390\n',
#    '64%\n',
#    '620\n',
#    '9%\n',
#    '380\n',
#    '61%\n',
#    '610\n',
#    '8%\n',
#    '370\n',
#    '57%\n',
#    '600\n',
#    '7%\n',
#    '360\n',
#    ...],
#   'h1': ['GMAT 2019 Registration, Exam Date, Pattern, Syllabus'],
#   'h2': ['GMAT 2019 Highlights',
#    'Must See Articles',
#    'Fee Structure',
#    'Sample/Mock Papers',
#    'GMATNews',
#    'Comments',
#    'Shivanshi Rathaur',
#    'subscribe to our news letter']},
#  {'keyword': 'gmat',
#   'rank': 2,
#   'title': 'GMAT Exam 2019 - Registration, Syllabus, Eligibility, Fees, Pattern & Result',
#   'description': 'Feb 11, 2019 - The full form of GMAT is Graduate Management Admission Test. ... Recent updates in GMAT: The Graduate Management Admission Council has shortened the GMAT exam by 30 minutes which will be effective from 16 April 2018. ... GMAT scores for Top MBA Colleges in USA.',
#   'link': 'https://studyabroad.shiksha.com/exams/gmat',
#   'doc': ['\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Enter',
#    'course,',
#    'college,',
#    'country',
#    'or',
#    'exam\n',
#    'Search\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Login\n',
#    '\n',
#    '|\n',
#    '\n',
#    'Sign',
#    'Up\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '0\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Menu\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Countries\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beginner',
#    'doubts\n',
#    'Best',
#    'country',
#    'to',
#    'study',
#    'abroad?\n',
#    'Most',
#    'affordable',
#    'countries?\n',
#    'Most',
#    'immigration',
#    'friendly',
#    'country?\n',
#    'Country',
#    'with',
#    'best',
#    'education',
#    'system?\n',
#    'How',
#    'to',
#    'choose',
#    'the',
#    'right',
#    'country?\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'USA\n',
#    'Downloads\n',
#    'Beginner',
#    'Guide\n',
#    'Visa',
#    'Guide\n',
#    'Living',
#    'in',
#    'USA\n',
#    'Average',
#    'living',
#    'costs\n',
#    'Part',
#    'time',
#    'work\n',
#    'Post',
#    'study',
#    'work\n',
#    'Popular',
#    'job',
#    'sectors\n',
#    'Explore\n',
#    'Universities',
#    'in',
#    'USA\n',
#    'Study',
#    'in',
#    'USA\n',
#    'Scholarships',
#    'in',
#    'USA\n',
#    '\n',
#    '\n',
#    '\n',
#    'Canada\n',
#    'Downloads\n',
#    'Beginner',
#    'Guide\n',
#    'Visa',
#    'Guide\n',
#    'Living',
#    'in',
#    'Canada\n',
#    'Average',
#    'living',
#    'costs\n',
#    'Part',
#    'time',
#    'work\n',
#    'Post',
#    'study',
#    'work\n',
#    'Popular',
#    'job',
#    'sectors\n',
#    'Explore\n',
#    'Universities',
#    'in',
#    'Canada\n',
#    'Study',
#    'in',
#    'Canada\n',
#    'Scholarships',
#    'in',
#    'Canada\n',
#    'SPP',
#    'colleges\n',
#    '\n',
#    '\n',
#    '\n',
#    'Australia\n',
#    'Downloads\n',
#    'Beginner',
#    'Guide\n',
#    'Visa',
#    'Guide\n',
#    'Living',
#    'in',
#    'Australia\n',
#    'Average',
#    'living',
#    'costs\n',
#    'Part',
#    'time',
#    'work\n',
#    'Post',
#    'study',
#    'work\n',
#    'Popular',
#    'job',
#    'sectors\n',
#    'Explore\n',
#    'Universities',
#    'in',
#    'Australia\n',
#    'Study',
#    'in',
#    'Australia\n',
#    'Scholarships',
#    'in',
#    'Australia\n',
#    '\n',
#    '\n',
#    '\n',
#    'UK\n',
#    'Downloads\n',
#    'Beginner',
#    'Guide\n',
#    'Visa',
#    'Guide\n',
#    'Living',
#    'in',
#    'UK\n',
#    'Average',
#    'living',
#    'costs\n',
#    'Part',
#    'time',
#    'work\n',
#    'Post',
#    'study',
#    'work\n',
#    'Popular',
#    'job',
#    'sectors\n',
#    'Explore\n',
#    'Universities',
#    'in',
#    'UK\n',
#    'Study',
#    'in',
#    'UK\n',
#    'Scholarships',
#    'in',
#    'UK\n',
#    '\n',
#    '\n',
#    '\n',
#    'More',
#    'countries\n',
#    'Popular',
#    'in',
#    'Europe\n',
#    'Study',
#    'in',
#    'France\n',
#    'Study',
#    'in',
#    'Germany\n',
#    'Study',
#    'in',
#    'Netherlands\n',
#    'Study',
#    'in',
#    'Sweden\n',
#    'Also',
#    'popular\n',
#    'Study',
#    'in',
#    'New',
#    'Zealand\n',
#    'Study',
#    'in',
#    'Singapore\n',
#    'Explore',
#    'all',
#    'countries\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Exams\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beginner',
#    'doubts\n',
#    'Which',
#    'exam',
#    'to',
#    'give',
#    'for',
#    'which',
#    'course',
#    '&',
#    'country?\n',
#    'IELTS',
#    'v/s',
#    'TOEFL',
#    'v/s',
#    'PTE?\n',
#    'IELTS',
#    'academic',
#    'V/s',
#    'IELTS',
#    'general?\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'IELTS\n',
#    'IELTS',
#    'Overview\n',
#    'IELTS',
#    'Results',
#    '/',
#    'Score\n',
#    'IELTS',
#    'Dates\n',
#    'IELTS',
#    'Registration\n',
#    'IELTS',
#    'Syllabus\n',
#    'IELTS',
#    'Sample',
#    '/',
#    'Practice',
#    'Paper\n',
#    '\n',
#    'TOEFL\n',
#    'TOEFL',
#    'Overview\n',
#    'TOEFL',
#    'Dates\n',
#    'TOEFL',
#    'Results',
#    '/',
#    'Scores\n',
#    'TOEFL',
#    'Registration\n',
#    'TOEFL',
#    'Syllabus\n',
#    'TOEFL',
#    'Sample',
#    '/',
#    'Practice',
#    'Papers\n',
#    '\n',
#    '\n',
#    '\n',
#    'PTE\n',
#    'PTE',
#    'Overview\n',
#    'PTE',
#    'Results',
#    '/',
#    'Scores\n',
#    'PTE',
#    'Sample',
#    '/',
#    'Practice',
#    'Papers\n',
#    'PTE',
#    'Registration\n',
#    'PTE',
#    'Dates\n',
#    'PTE',
#    'Syllabus\n',
#    '\n',
#    'GRE\n',
#    'GRE',
#    'Overview\n',
#    'GRE',
#    'Syllabus\n',
#    'GRE',
#    'Test',
#    'center\n',
#    'GRE',
#    'Scores',
#    '/',
#    'Results\n',
#    'GRE',
#    'Sample',
#    '/',
#    'Practice',
#    'Paper\n',
#    'GRE',
#    'Eligibility\n',
#    'GRE',
#    'Dates\n',
#    '\n',
#    '\n',
#    '\n',
#    'GMAT\n',
#    'GMAT',
#    'Overview\n',
#    'GMAT',
#    'Syllabus\n',
#    'GMAT',
#    'Test',
#    'center\n',
#    'GMAT',
#    'Scores',
#    '/',
#    'Results\n',
#    'GMAT',
#    'Sample',
#    'Paper\n',
#    'GMAT',
#    'Registration\n',
#    'GMAT',
#    'Eligibility\n',
#    'GMAT',
#    'Dates\n',
#    '\n',
#    'SAT\n',
#    'SAT',
#    'Overview\n',
#    'SAT',
#    'Results',
#    '/',
#    'Scores\n',
#    'SAT',
#    'Registration\n',
#    'SAT',
#    'Test',
#    'center\n',
#    'SAT',
#    'Syllabus\n',
#    'SAT',
#    'Sample',
#    '/',
#    'Practice',
#    'Papers\n',
#    'SAT',
#    'Dates\n',
#    '\n',
#    '\n',
#    '\n',
#    'Find',
#    'Colleges',
#    'by',
#    'Exam\n',
#    'Accepting',
#    'GRE\n',
#    'MS',
#    'colleges\n',
#    'MBA',
#    'colleges\n',
#    'Accepting',
#    'GMAT\n',
#    'MBA',
#    'colleges\n',
#    'MS',
#    'Colleges\n',
#    'Accepting',
#    'SAT\n',
#    'BE/BTech',
#    'colleges\n',
#    'Accepting',
#    'IELTS\n',
#    'MS',
#    'colleges\n',
#    'MBA',
#    'colleges\n',
#    'BE/BTech',
#    'colleges\n',
#    'Accepting',
#    'TOEFL\n',
#    'MS',
#    'colleges\n',
#    'MBA',
#    'colleges\n',
#    'BE/BTech',
#    'colleges\n',
#    'Accepting',
#    'PTE\n',
#    'MS',
#    'colleges\n',
#    'MBA',
#    'colleges\n',
#    'BE/BTech',
#    'colleges\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Colleges\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beginner',
#    'doubts\n',
#    'How',
#    'to',
#    'choose',
#    'right',
#    'college?\n',
#    'Do',
#    'college',
#    'rankings',
#    'matter?\n',
#    'Difference',
#    'between',
#    'university',
#    '&',
#    'college?\n',
#    'Difference',
#    'between',
#    'MS',
#    'Analytics',
#    '&',
#    'MBA?\n',
#    'MBA',
#    'v/s',
#    'MS,',
#    'which',
#    'is',
#    'better?\n',
#    'BBA',
#    'v/s',
#    'BTech,',
#    'which',
#    'is',
#    'better?\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'MS',
#    'Colleges\n',
#    'By',
#    'Specialization\n',
#    'MS',
#    'in',
#    'Computer',
#    'Science',
#    '&Engg;\n',
#    'MS',
#    'in',
#    'IT/MIS\n',
#    'MS',
#    'in',
#    'Electrical',
#    '&',
#    'Electronics\n',
#    'MS',
#    'in',
#    'Mechanical\n',
#    'MS',
#    'in',
#    'all',
#    'specializations\n',
#    'By',
#    'Country\n',
#    'MS',
#    'in',
#    'USA\n',
#    'MS',
#    'in',
#    'Canada\n',
#    'MS',
#    'in',
#    'Australia\n',
#    'MS',
#    'in',
#    'UK\n',
#    'MS',
#    'in',
#    'all',
#    'countries\n',
#    'By',
#    'Rank\n',
#    'Top',
#    'MS',
#    'colleges\n',
#    '\n',
#    '\n',
#    '\n',
#    'MBA',
#    'Colleges\n',
#    'By',
#    'Specialization\n',
#    'MBA',
#    'in',
#    'Finance\n',
#    'MBA',
#    'in',
#    'Marketing\n',
#    'MBA',
#    'in',
#    'International',
#    'Business\n',
#    'MBA',
#    'in',
#    'Human',
#    'Resources\n',
#    'MBA',
#    'in',
#    'all',
#    'specializations\n',
#    'By',
#    'Country\n',
#    'MBA',
#    'in',
#    'USA\n',
#    'MBA',
#    'in',
#    'Canada\n',
#    'MBA',
#    'in',
#    'Australia\n',
#    'MBA',
#    'in',
#    'UK\n',
#    'MBA',
#    'in',
#    'all',
#    'countries\n',
#    'By',
#    'Rank\n',
#    'Top',
#    'MBA',
#    'colleges',
#    'in',
#    'USA\n',
#    '\n',
#    '\n',
#    '\n',
#    'BE/BTech',
#    'Colleges\n',
#    'By',
#    'Specialization\n',
#    'BE/BTech',
#    'in',
#    'Computer',
#    'Science',
#    '&',
#    'Engg\n',
#    'BE/BTech',
#    'in',
#    'IT/MIS\n',
#    'BE/BTech',
#    'in',
#    'Electrical\n',
#    'BE/BTech',
#    'in',
#    'Mechanical\n',
#    'BE/BTech',
#    'in',
#    'all',
#    'specializations\n',
#    'By',
#    'Country\n',
#    'BE/BTech',
#    'in',
#    'USA\n',
#    'BE/BTech',
#    'in',
#    'Canada\n',
#    'BE/BTech',
#    'in',
#    'Australia\n',
#    'BE/BTech',
#    'in',
#    'UK\n',
#    'BE/BTech',
#    'in',
#    'all',
#    'countries\n',
#    '\n',
#    '\n',
#    '\n',
#    'More',
#    'courses\n',
#    'Masters\n',
#    'Masters',
#    'in',
#    'Hospitality\n',
#    'Masters',
#    'in',
#    'Journalism\n',
#    'Masters',
#    'in',
#    'Accounting\n',
#    'Masters',
#    'in',
#    'Civil',
#    'Engineering\n',
#    'Masters',
#    'in',
#    'Aerospace',
#    'Engineering\n',
#    'Bachelors\n',
#    'BBA\n',
#    'Bachelors',
#    'in',
#    'Fashion\n',
#    'Bachelors',
#    'in',
#    'Media\n',
#    'Diploma/Certificate\n',
#    'Computers',
#    'Diploma\n',
#    'Business',
#    'Diploma\n',
#    'Engineering',
#    'Diploma\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Finances\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beginner',
#    'doubts\n',
#    'Can',
#    'you',
#    'study',
#    'abroad',
#    'for',
#    'free?\n',
#    'Types',
#    'of',
#    'scholarships',
#    'for',
#    'Indian',
#    'students?\n',
#    'How',
#    'to',
#    'write',
#    'scholarship',
#    'essay?\n',
#    'What',
#    'are',
#    'chances',
#    'of',
#    'receiving',
#    'scholarship?\n',
#    'When',
#    'to',
#    'start',
#    'thinking',
#    'about',
#    'finances?\n',
#    'Financial',
#    'documents',
#    'required',
#    'for',
#    'abroad',
#    'studies?\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Scholarships\n',
#    'By',
#    'country\n',
#    'Scholarships',
#    'for',
#    'USA\n',
#    'Scholarships',
#    'for',
#    'Canada\n',
#    'Scholarships',
#    'for',
#    'Australia\n',
#    'Scholarships',
#    'for',
#    'UK\n',
#    'Scholarships',
#    'for',
#    'all',
#    'countries\n',
#    'By',
#    'course\n',
#    'Scholarships',
#    'for',
#    'Masters\n',
#    'Scholarships',
#    'for',
#    'Bachelors\n',
#    'By',
#    'Type',
#    '(for',
#    'Masters)\n',
#    'Need',
#    'based',
#    'scholarships\n',
#    'Merit',
#    'based',
#    'scholarships\n',
#    'By',
#    'Provider',
#    '(for',
#    'Masters)\n',
#    'College',
#    'specific',
#    'scholarships\n',
#    'Scholarships',
#    'by',
#    'external',
#    'agencies\n',
#    'For',
#    'special',
#    'cases',
#    '(for',
#    'Masters)\n',
#    'For',
#    'differently',
#    'abled\n',
#    'For',
#    'women\n',
#    '\n',
#    '\n',
#    '\n',
#    'Education',
#    'Loans\n',
#    'Apply\n',
#    'Apply',
#    'for',
#    'Education',
#    'Loan\n',
#    'Guides\n',
#    'Step',
#    'by',
#    'step',
#    'guide',
#    'for',
#    'loans\n',
#    'Guide',
#    'to',
#    'student',
#    'loans\n',
#    'Common',
#    'doubts\n',
#    'Eligibility',
#    'criteria',
#    'for',
#    'a',
#    'loan\n',
#    'Documents',
#    'required',
#    'for',
#    'a',
#    'loan\n',
#    'Loan',
#    'v/s',
#    'Self',
#    'Funding\n',
#    'Top',
#    'education',
#    'loan',
#    'providers\n',
#    'What',
#    'are',
#    'collateralized',
#    'loans?\n',
#    'Public',
#    'v/s',
#    'private',
#    'loan',
#    'providers\n',
#    'By',
#    'Country\n',
#    'Education',
#    'loan',
#    'for',
#    'USA\n',
#    'Education',
#    'loan',
#    'for',
#    'Canada\n',
#    'Education',
#    'loan',
#    'for',
#    'Australia\n',
#    'Education',
#    'loan',
#    'for',
#    'UK\n',
#    'Education',
#    'loan',
#    'for',
#    'Germany\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Apply\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'Beginner',
#    'doubts\n',
#    'How',
#    'to',
#    'apply',
#    'to',
#    'colleges',
#    'abroad?\n',
#    'Can',
#    'students',
#    'apply',
#    'on',
#    'their',
#    'own?\n',
#    'Self',
#    'apply',
#    'v/s',
#    'outside',
#    'agents?\n',
#    'Should',
#    'you',
#    'use',
#    'paid',
#    'or',
#    'free',
#    'consultants?\n',
#    'Do',
#    'backlogs',
#    'matter?\n',
#    'Common',
#    'mistakes',
#    'in',
#    'student',
#    'applications?\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    '\n',
#    'SOP\n',
#    'Common',
#    'doubts\n',
#    'What',
#    'is',
#    'SOP?\n',
#    'Common',
#    'mistakes',
#    'in',
#    'SOP\n',
#    'What',
#    'makes',
#    'a',
#    'good',
#    'SOP?\n',
#    'Downloads',
#    'by',
#    'course\n',
#    'Sample',
#    'SOP',
#    'for',
#    'MBA\n',
#    'Sample',
#    'SOP',
#    'for',
#    'MS\n',
#    'Sample',
#    'SOP',
#    'for',
#    'Bachelors\n',
#    'Sample',
#    'SOP',
#    'for',
#    'PhD\n',
#    'Sample',
#    'SOP',
#    'for',
#    ...],
#   'h1': ['GMAT'],
#   'h2': ['GMAT 2019 Exam',
#    'Related articles',
#    'Colleges accepting GMAT',
#    'GMAT Dates',
#    'GMAT FAQs',
#    '213 Comments',
#    'You might also like']}]

# %%
! pip freeze > requirements.txt
